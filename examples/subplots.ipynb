# %%
import os
import sys
import pandas as pd
import numpy as np

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from plotly_chart_builder.plotly_chart_builder import PlotlyChart

chart = PlotlyChart()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Create data
index = ['Production', 'Assembly', 'Design']
values = {'Unit 1': [55, 35, 10], 
         'Unit 2': [50, 30, 20],
         'Unit 3': [45, 45, 10],
         'Unit 4': [40, 45, 15],
         }

data = pd.DataFrame(data=values, index=index)

# Create chart
layout = chart.layout(title='Pie Plots', height=600, width=600)
chart.pie_subplots(data=data.to_dict(), rows=2, cols=2,
                   titles=[*data.to_dict().keys()], layout=layout,
                   hoverinfo='label+name', textinfo='value')
# Out:
# <div>
#
#
#             <div id="345d77c7-fe04-406b-8262-9c13be45991a" class="plotly-graph-div" style="height:600px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("345d77c7-fe04-406b-8262-9c13be45991a")) {
#                     Plotly.newPlot(
#                         '345d77c7-fe04-406b-8262-9c13be45991a',
#                         [{"domain": {"x": [0.0, 0.45], "y": [0.625, 1.0]}, "hole": 0.3, "hoverinfo": "label+name", "labels": ["Production", "Assembly", "Design"], "marker": {"line": {"color": "#202534", "width": 5}}, "name": "Unit 1", "textinfo": "value", "type": "pie", "values": [55, 35, 10]}, {"domain": {"x": [0.55, 1.0], "y": [0.625, 1.0]}, "hole": 0.3, "hoverinfo": "label+name", "labels": ["Production", "Assembly", "Design"], "marker": {"line": {"color": "#202534", "width": 5}}, "name": "Unit 2", "textinfo": "value", "type": "pie", "values": [50, 30, 20]}, {"domain": {"x": [0.0, 0.45], "y": [0.0, 0.375]}, "hole": 0.3, "hoverinfo": "label+name", "labels": ["Production", "Assembly", "Design"], "marker": {"line": {"color": "#202534", "width": 5}}, "name": "Unit 3", "textinfo": "value", "type": "pie", "values": [45, 45, 10]}, {"domain": {"x": [0.55, 1.0], "y": [0.0, 0.375]}, "hole": 0.3, "hoverinfo": "label+name", "labels": ["Production", "Assembly", "Design"], "marker": {"line": {"color": "#202534", "width": 5}}, "name": "Unit 4", "textinfo": "value", "type": "pie", "values": [40, 45, 15]}],
#                         {"annotations": [{"font": {"color": "lightgrey", "size": 12}, "showarrow": false, "text": "Unit 1", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"color": "lightgrey", "size": 12}, "showarrow": false, "text": "Unit 2", "x": 0.775, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"color": "lightgrey", "size": 12}, "showarrow": false, "text": "Unit 3", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 0.375, "yanchor": "bottom", "yref": "paper"}, {"font": {"color": "lightgrey", "size": 12}, "showarrow": false, "text": "Unit 4", "x": 0.775, "xanchor": "center", "xref": "paper", "y": 0.375, "yanchor": "bottom", "yref": "paper"}], "autosize": false, "height": 600, "legend": {"bordercolor": "#202534", "borderwidth": 0, "font": {"color": "lightgrey", "family": "sans-serif", "size": 12}, "itemclick": "toggle", "itemdoubleclick": "toggleothers", "orientation": "v", "traceorder": "normal", "valign": "middle", "x": 1.02, "xanchor": "left", "y": 1, "yanchor": "middle"}, "margin": {"b": 75, "l": 75, "pad": 10, "r": 50, "t": 75}, "paper_bgcolor": "#202534", "plot_bgcolor": "#202534", "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777777777 ...

# %%
path = '../data/supplier_invoices_cleaned.xlsx'
dtypes = {'År': 'Int64', 'Måned': 'Int64', 'Behandlingstid': 'Int64'}
df = pd.read_excel(path, sheet_name='data', dtype=dtypes)

# %%
data_dict = {}
for loc in ['Skurve', 'Hjørungavåg', 'Verdal', 'Hønefoss']:
    table = df.loc[df['Lokasjon'] == loc]
    table = table.groupby(['Partnerbeskrivelse']).agg(
                    spend=pd.NamedAgg(column='Sum', aggfunc='sum'),
                    ant_faktura=pd.NamedAgg(column='Bilagsnummer', aggfunc=pd.Series.nunique))
    data_dict.update({loc: {'y': table['spend'].values, 
                            'x': table['ant_faktura'].values,
                            'names': table.index}})
    
layout = chart.subplots_layout(title='Spend/antall faktura fordelt på leverandør/lokasjon',
                               height=800, width=800)


chart.scatter_subplots(data_dict, rows=2, cols=2, titles=list(data_dict.keys()), layout=layout)
# Out:
# <div>
#
#
#             <div id="f0b606d8-b047-4ab2-90d6-dbd1e745122d" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f0b606d8-b047-4ab2-90d6-dbd1e745122d")) {
#                     Plotly.newPlot(
#                         'f0b606d8-b047-4ab2-90d6-dbd1e745122d',
#                         [{"mode": "markers", "name": "Skurve", "text": ["A FALKENBERG EFTF AS", "A/S Nestle Norge", "A/S SKANDINAVISK SP\u00c6NDBETON", "A3 TRANSPORT AS", "AANESTAD SERVICE AS", "AARSVOLD AS", "AARSVOLD KRAN & HYDRAULIKK....", "ABV AS.", "ADDA BYGGKJEMI AS", "AEK CONSULTING (SEK)", "AGA AS", "AHLSELL AS.", "AIT Bjerch AS", "AJ PRODUKTER A/S", "AMERICAN EXPRESS CARD SERVICE.", "AMUNDSEN SVEISE & MEK VERKSTED", "APPLUS LABORATORIES AS", "ARBEIDSMILJ\u00d8SENTERET", "AS Metall Teknikk", "ASI AUTOMATIKK AS.", "Aarsvold Kran og Hydraulikk AS", "Abra iride", "Acies A/S", "Alf l. Larsen A/S", "Alfa Inkasso AS", "Alfa Solution AS", "Allianceplus AS", "ArnCon Consulting AB", "Axactor Norway AS", "B GROUP UAB", "BAHS Kapital AS", "BASF AS", "BERGEN KRAN OG CARGO A/S.", "BILTEMA NORGE AS", "BOLKAN TRANS H\u00d8NEFOSS AS", "BOSS EUROPE AS", "BSAFE SYSTEM AS", "Bama Storkj\u00f8kken AS", "Barstad Service", "Bedriftssenteret Buskerud AS Netcom", "Betongbygget AS, C/O Maaseide Promotion", "Betongelementforeningen", "Betongsaging A/S", "Bitmap As", "Block Berge Bygg AS", "Bl\u00fccher Norway AS", "Bolkan Trans Namsos AS..", "Brevetti Nordic AS", "Brilleland AS", "Bryne Plast AS", "Bryne R\u00f8r AS", "Br\u00f8drene Dahl A s", "Bufab Norge AS", "Byggefirma Kjetil Hetland AS", "B\u00f8ndenes innkj\u00f8pslag BA", "C DAHM MASKINFORRETNING A/S", "CANON NORGE AS", "CARL STAHL AS", "COMBILIFT LTD", "CONPARTS APS (DKK)", "CRAMO AS", "Canon Norge AS", "Carbolline Norge AS", "Circle K Norge AS", "City Apartment Hotel AS", "Clas Ohlson AS.", "Cobuilder AS", "Complexsad Norway AS", "Coop Gjesdal SA", "Cowi AS", "DAW Nordic AB", "DHL Express (Norway) AS", "DHL Global Forwarding Freight Norway", "DNF AS.", "DNV GL AS", "DSV Roads AS", "Dekk1 J\u00e6ren AS.", "Duri Fagprofil AS", "E A Smith AS", "ECS Automasjon", "ELEMATIC OY AB (EUR)", "ENERGI SALG NORGE AS", "EURIFINS ENVIRONMENT", "EURONICS Sinus Elektro Handel AS", "EUROPRIS BUTIKKDRIFT AS", "Ecoratio (EUR)", "Ecus & Niels Bonde Spedition Aps", "Egeland Plast A S", "Eik Senteret Klepp J\u00e6ren Traktorsenter A", "Einar Roals\u00f8 Plastindustri", "Elektroskandia Norge AS", "Elementmontasje Vest", "Elfa Elektronikk AS", "Elixia Vest.", "Elkem ASA Materials", "Ementor Norge AS", "Enviro Pac AS", "Enwa Support as", "Espenes A S", "Express Steel Service AS", "FELLESORDNINGEN FOR AVTALEFESTET PENSJON", "FERRONOR AS", "FINN.NO", "FIRST RENT A CAR NORWAY AS", "FJELLINJEN AS", "FLEKSI BEMANNING AS", "FLT EVU-fond", "FNsteel HJULSBRO AB (EUR).", "FREJA TRANSPORT & LOGISTICKS AS", "Felleskj\u00f8pet Rogaland Agder.", "Finans2 AS", "Foma Norge AS", "Forsand Sandkompani AS", "Franzefoss Gjenvinning AS", "Franzefoss Milj\u00f8Kalk AS", "Fritz\u00f8e Engros AS", "Fyllingen Elektromaskin AS", "GV Reklame AS", "Gjesdal Kommune", "Gjesdal Sandbl\u00e5sning Jan R Gravdal", "Global Steel Wire S.A.", "Gulv og Tak A S", "Gunnar H\u00f8ien AS", "HAARUP MASKINFABRIK A/S (DKK)", "HANSMARK R AS", "HBC-radiomatic Norge AS", "HOGNESTAD AS", "HOTELL HADELAND", "HP Schou AS", "HUSMANNSKOST AS.", "HYDROSCAND AS", "Halfen AS", "Hatteland Elektriske AS", "Haucon Norge AS.", "Haugen Drift AS", "Hetronic Norge AS", "Hillesland AS", "Hillev\u00e5g Elektro-Diesel A S", "Honeywell Life Safety AS", "Hotel Neptun", "Hotel-link AS", "IKM Inspection AS", "INDUSTRIKRAN NORGE AS", "INTRUM JUSTITIA AS", "ISS Facility Services A/S..", "Industrisalg AS-Sandnes.", "Ing H Asmyhr A S", "Interoute Managed Services Norge AS", "Invisible Connections AS", "JLS Mekaniske", "JOBZONE AS.", "JS Transport AS", "JTR Gruppen AS", "Jarl Westerg\u00e5rd EN\u00d8k-r\u00e5dgiver", "Jetpak Norge AS.", "JoB Arkitekter AS", "Joker \u00c5lg\u00e5rd", "Jungheinrich Norge AS", "J\u00e6ren Utleie AS", "KALLJAC AB", "KGH CUSTOMS SERVICES AS....", "KIS Vest AS", "KONTROLLR\u00c5DET FOR BETONGPRODUKTER.", "KRISTIANSAND MONTASJE OG INDUSTRISERVICE", "KUEHNE + NAGEL UAB", "Kafe J\u00e6rbuen, Jette Bjorland", "Kaffeknappen Norge AS", "Kamst\u00e5l AS", "Kaspo M ...

# %%
data_dict = {}
for loc in ['Skurve', 'Hjørungavåg', 'Verdal', 'Hønefoss']:
    table = df.loc[df['Lokasjon'] == loc]
    table = table.groupby(['Partnerbeskrivelse']).agg(
                    spend=pd.NamedAgg(column='Sum', aggfunc='sum'),
                    ant_faktura=pd.NamedAgg(column='Bilagsnummer', aggfunc=pd.Series.nunique))
    data_dict.update({loc: {'y': table['spend'].values, 
                            'x': table['ant_faktura'].values,
                            'names': table.index}})

colors = chart.color_palette(color='darkred', palette_type='light', reverse=True, start_pos=2)
layout = chart.subplots_layout(title='Spend/antall faktura fordelt på leverandør/lokasjon',
                               height=800, width=800,
                              yaxis_title='Y-axis title',
                              xaxis_title='x-axis title',
                              color_palette=colors)


chart.scatter_subplots(data_dict, rows=2, cols=2, titles=list(data_dict.keys()), layout=layout)
# Out:
# <div>
#
#
#             <div id="82efb09e-eb8f-45e5-af4a-f11a0df953e6" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("82efb09e-eb8f-45e5-af4a-f11a0df953e6")) {
#                     Plotly.newPlot(
#                         '82efb09e-eb8f-45e5-af4a-f11a0df953e6',
#                         [{"mode": "markers", "name": "Skurve", "text": ["A FALKENBERG EFTF AS", "A/S Nestle Norge", "A/S SKANDINAVISK SP\u00c6NDBETON", "A3 TRANSPORT AS", "AANESTAD SERVICE AS", "AARSVOLD AS", "AARSVOLD KRAN & HYDRAULIKK....", "ABV AS.", "ADDA BYGGKJEMI AS", "AEK CONSULTING (SEK)", "AGA AS", "AHLSELL AS.", "AIT Bjerch AS", "AJ PRODUKTER A/S", "AMERICAN EXPRESS CARD SERVICE.", "AMUNDSEN SVEISE & MEK VERKSTED", "APPLUS LABORATORIES AS", "ARBEIDSMILJ\u00d8SENTERET", "AS Metall Teknikk", "ASI AUTOMATIKK AS.", "Aarsvold Kran og Hydraulikk AS", "Abra iride", "Acies A/S", "Alf l. Larsen A/S", "Alfa Inkasso AS", "Alfa Solution AS", "Allianceplus AS", "ArnCon Consulting AB", "Axactor Norway AS", "B GROUP UAB", "BAHS Kapital AS", "BASF AS", "BERGEN KRAN OG CARGO A/S.", "BILTEMA NORGE AS", "BOLKAN TRANS H\u00d8NEFOSS AS", "BOSS EUROPE AS", "BSAFE SYSTEM AS", "Bama Storkj\u00f8kken AS", "Barstad Service", "Bedriftssenteret Buskerud AS Netcom", "Betongbygget AS, C/O Maaseide Promotion", "Betongelementforeningen", "Betongsaging A/S", "Bitmap As", "Block Berge Bygg AS", "Bl\u00fccher Norway AS", "Bolkan Trans Namsos AS..", "Brevetti Nordic AS", "Brilleland AS", "Bryne Plast AS", "Bryne R\u00f8r AS", "Br\u00f8drene Dahl A s", "Bufab Norge AS", "Byggefirma Kjetil Hetland AS", "B\u00f8ndenes innkj\u00f8pslag BA", "C DAHM MASKINFORRETNING A/S", "CANON NORGE AS", "CARL STAHL AS", "COMBILIFT LTD", "CONPARTS APS (DKK)", "CRAMO AS", "Canon Norge AS", "Carbolline Norge AS", "Circle K Norge AS", "City Apartment Hotel AS", "Clas Ohlson AS.", "Cobuilder AS", "Complexsad Norway AS", "Coop Gjesdal SA", "Cowi AS", "DAW Nordic AB", "DHL Express (Norway) AS", "DHL Global Forwarding Freight Norway", "DNF AS.", "DNV GL AS", "DSV Roads AS", "Dekk1 J\u00e6ren AS.", "Duri Fagprofil AS", "E A Smith AS", "ECS Automasjon", "ELEMATIC OY AB (EUR)", "ENERGI SALG NORGE AS", "EURIFINS ENVIRONMENT", "EURONICS Sinus Elektro Handel AS", "EUROPRIS BUTIKKDRIFT AS", "Ecoratio (EUR)", "Ecus & Niels Bonde Spedition Aps", "Egeland Plast A S", "Eik Senteret Klepp J\u00e6ren Traktorsenter A", "Einar Roals\u00f8 Plastindustri", "Elektroskandia Norge AS", "Elementmontasje Vest", "Elfa Elektronikk AS", "Elixia Vest.", "Elkem ASA Materials", "Ementor Norge AS", "Enviro Pac AS", "Enwa Support as", "Espenes A S", "Express Steel Service AS", "FELLESORDNINGEN FOR AVTALEFESTET PENSJON", "FERRONOR AS", "FINN.NO", "FIRST RENT A CAR NORWAY AS", "FJELLINJEN AS", "FLEKSI BEMANNING AS", "FLT EVU-fond", "FNsteel HJULSBRO AB (EUR).", "FREJA TRANSPORT & LOGISTICKS AS", "Felleskj\u00f8pet Rogaland Agder.", "Finans2 AS", "Foma Norge AS", "Forsand Sandkompani AS", "Franzefoss Gjenvinning AS", "Franzefoss Milj\u00f8Kalk AS", "Fritz\u00f8e Engros AS", "Fyllingen Elektromaskin AS", "GV Reklame AS", "Gjesdal Kommune", "Gjesdal Sandbl\u00e5sning Jan R Gravdal", "Global Steel Wire S.A.", "Gulv og Tak A S", "Gunnar H\u00f8ien AS", "HAARUP MASKINFABRIK A/S (DKK)", "HANSMARK R AS", "HBC-radiomatic Norge AS", "HOGNESTAD AS", "HOTELL HADELAND", "HP Schou AS", "HUSMANNSKOST AS.", "HYDROSCAND AS", "Halfen AS", "Hatteland Elektriske AS", "Haucon Norge AS.", "Haugen Drift AS", "Hetronic Norge AS", "Hillesland AS", "Hillev\u00e5g Elektro-Diesel A S", "Honeywell Life Safety AS", "Hotel Neptun", "Hotel-link AS", "IKM Inspection AS", "INDUSTRIKRAN NORGE AS", "INTRUM JUSTITIA AS", "ISS Facility Services A/S..", "Industrisalg AS-Sandnes.", "Ing H Asmyhr A S", "Interoute Managed Services Norge AS", "Invisible Connections AS", "JLS Mekaniske", "JOBZONE AS.", "JS Transport AS", "JTR Gruppen AS", "Jarl Westerg\u00e5rd EN\u00d8k-r\u00e5dgiver", "Jetpak Norge AS.", "JoB Arkitekter AS", "Joker \u00c5lg\u00e5rd", "Jungheinrich Norge AS", "J\u00e6ren Utleie AS", "KALLJAC AB", "KGH CUSTOMS SERVICES AS....", "KIS Vest AS", "KONTROLLR\u00c5DET FOR BETONGPRODUKTER.", "KRISTIANSAND MONTASJE OG INDUSTRISERVICE", "KUEHNE + NAGEL UAB", "Kafe J\u00e6rbuen, Jette Bjorland", "Kaffeknappen Norge AS", "Kamst\u00e5l AS", "Kaspo M ...
