# %%
import os
import sys
import pandas as pd
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from plotly_chart_builder.plotly_chart_builder import PlotlyChart

chart = PlotlyChart()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = {'scatter_1': {'x': np.linspace(0, 10, 100), 'y': np.sin(t)}}

layout = chart.layout(xaxis_showgrid=True, width=600, height=400)
chart.scatter(data=data, layout=layout)
# Out:
# <div>
#
#
#             <div id="bd97819d-bb00-4f27-9ef3-3f0bad68ac43" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd97819d-bb00-4f27-9ef3-3f0bad68ac43")) {
#                     Plotly.newPlot(
#                         'bd97819d-bb00-4f27-9ef3-3f0bad68ac43',
# ...

# %%
from scipy.stats import skewnorm

# create data
data = {}
for sample, skew in list(zip(['sample 1', 'sample 2', 'sample 3'], [10, 50, 70])):
    data.update({sample: 
                 {'x': skewnorm.rvs(skew, size=100),
                  'y': skewnorm.rvs(skew, size=100)}})

# create chart                        
layout = chart.layout(xaxis_showgrid=True)
chart.scatter(data=data, layout=layout)
# Out:
# <div>
#
#
#             <div id="c209433b-8bc9-43d5-bf7a-c8a2ebefcbb4" class="plotly-graph-div" style="height:600px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c209433b-8bc9-43d5-bf7a-c8a2ebefcbb4")) {
#                     Plotly.newPlot(
#                         'c209433b-8bc9-43d5-bf7a-c8a2ebefcbb4',
# ...

# %%
data
# Out:
# {'sample 1': {'x': array([ 0.69359092,  1.03427267,  1.68382378,  0.71757235,  0.55012326,
#           1.49199904,  0.46144535,  0.63373023,  1.48634376,  0.61351873,
#           0.70641132,  0.17999978,  0.75047206,  0.27498362,  0.59928395,
#           1.66722747,  1.06186764,  0.2958762 ,  1.26182672,  0.56651668,
#           0.6679923 ,  1.8479057 ,  0.32854005,  0.35479022,  0.16831128,
#           0.327454  ,  0.55427482,  0.8730213 ,  0.01255152,  1.00308634,
#           0.24062388,  1.83074003,  0.34306459,  1.20805131,  0.10953543,
#           1.1363413 ,  0.38225881,  0.63208568,  1.56651398,  0.59982471,
#           0.71743407,  0.37313519,  0.4756013 ,  0.74951479,  0.70698869,
#           0.60886315,  1.05135827,  2.08047389,  0.61152145,  0.16095845,
#           0.1077403 ,  0.24794434,  0.33440638,  1.37948554,  0.78184503,
#           0.39264346,  0.89487152, -0.16711957,  0.12139535,  0.84123075,
# ...

# %%
pd.read_excel()
